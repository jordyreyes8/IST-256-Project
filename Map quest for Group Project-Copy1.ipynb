# %%
## https://developer.mapquest.com/documentation/open/directions-api/route/get/
import requests

url = "http://open.mapquestapi.com/directions/v2/route?"
key = "VB4ILPzMP7JFAFiVmmIYhkGGlDo7xOy0"
start_pt = "1000 Irving Ave, Syracuse, NY"
end_pt = "201 Euclid Ave, Syracuse, NY"

parameters = {"key":key, "from": start_pt, "to": end_pt}

response = requests.get(url, params = parameters)
directions = response.json()
directions
# Out:
# {'route': {'hasTollRoad': False,
#   'hasBridge': False,
#   'boundingBox': {'lr': {'lng': -76.128929, 'lat': 43.035419},
#    'ul': {'lng': -76.1381, 'lat': 43.036327}},
#   'distance': 0.542,
#   'hasTimedRestriction': False,
#   'hasTunnel': False,
#   'hasHighway': False,
#   'computedWaypoints': [],
#   'routeError': {'errorCode': -400, 'message': ''},
#   'formattedTime': '00:02:21',
#   'sessionId': '5ea07b91-01a2-4ee4-02b4-22d4-0ac1e987c5b5',
#   'hasAccessRestriction': False,
#   'realTime': -1,
#   'hasSeasonalClosure': False,
#   'hasCountryCross': False,
#   'fuelUsed': 0.07,
#   'legs': [{'hasTollRoad': False,
#     'hasBridge': False,
#     'destNarrative': 'Proceed to 201 EUCLID AVENUE.',
#     'distance': 0.542,
#     'hasTimedRestriction': False,
#     'hasTunnel': False,
#     'hasHighway': False,
#     'index': 0,
#     'formattedTime': '00:02:21',
#     'origIndex': 1,
#     'hasAccessRestriction': False,
#     'hasSeasonalClosure': False,
# ...
